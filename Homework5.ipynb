# %% [markdown]
# ## Homework3

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('sIMG_8253.jpg',1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = cv2.medianBlur(img_gray,5)
img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img_gray,cv2.HOUGH_GRADIENT, 1, 20, param1 = 250, param2 = 55, minRadius = 0, maxRadius = 0)
circles = np.uint16(np.around(circles))

for c in circles[0,:]:

    center = (c[0],c[1])
    radius = c[2]

    # 바깥원
    cv2.circle(img_color,center,radius,(0,255,0),3)

    # 중심원
    cv2.circle(img_color,center,2,(0,0,255),3)



gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img = closing.copy()
contours, hierarchy = cv2.findContours(cont_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue

    if len(cnt) < 5:
        continue

    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img, ellipse, (0, 255, 0), 2)

cv2.imshow('detected circles',img_color)
cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshold", thresh)
# cv2.imshow("contours", img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b76fa191065a> in <module>
#       1 img = cv2.imread('sIMG_8253.jpg',1)
#       2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 3 img_gray = cv2.medianBlur(img_gray,5)
#       4 img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)
#       5
#
# NameError: name 'img_gray' is not defined

# %%
img = cv2.imread('sIMG_8254.jpg',1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = cv2.medianBlur(img_gray,5)
img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img_gray,cv2.HOUGH_GRADIENT, 1, 20, param1 = 250, param2 = 55, minRadius = 0, maxRadius = 0)
circles = np.uint16(np.around(circles))

for c in circles[0,:]:

    center = (c[0],c[1])
    radius = c[2]

    # 바깥원
    cv2.circle(img_color,center,radius,(0,255,0),3)

    # 중심원
    cv2.circle(img_color,center,2,(0,0,255),3)



gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img = closing.copy()
contours, hierarchy = cv2.findContours(cont_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue

    if len(cnt) < 5:
        continue

    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img, ellipse, (0, 255, 0), 2)

cv2.imshow('detected circles',img_color)
cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshold", thresh)
# cv2.imshow("contours", img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-638cb4445dad> in <module>
#       1 img = cv2.imread('sIMG_8254.jpg',1)
#       2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 3 img_gray = cv2.medianBlur(img_gray,5)
#       4 img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)
#       5
#
# NameError: name 'img_gray' is not defined

# %%
img = cv2.imread('sIMG_8255.jpg',1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = cv2.medianBlur(img_gray,5)
img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img_gray,cv2.HOUGH_GRADIENT, 1, 20, param1 = 250, param2 = 55, minRadius = 0, maxRadius = 0)
circles = np.uint16(np.around(circles))

for c in circles[0,:]:

    center = (c[0],c[1])
    radius = c[2]

    # 바깥원
    cv2.circle(img_color,center,radius,(0,255,0),3)

    # 중심원
    cv2.circle(img_color,center,2,(0,0,255),3)



gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img = closing.copy()
contours, hierarchy = cv2.findContours(cont_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue

    if len(cnt) < 5:
        continue

    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img, ellipse, (0, 255, 0), 2)

cv2.imshow('detected circles',img_color)
cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshold", thresh)
# cv2.imshow("contours", img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f0db14a2da20> in <module>
#       1 img = cv2.imread('sIMG_8255.jpg',1)
#       2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 3 img_gray = cv2.medianBlur(img_gray,5)
#       4 img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)
#       5
#
# NameError: name 'img_gray' is not defined

# %%
img = cv2.imread('sIMG_8256.jpg',1)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = cv2.medianBlur(img_gray,5)
img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)

circles = cv2.HoughCircles(img_gray,cv2.HOUGH_GRADIENT, 1, 20, param1 = 250, param2 = 55, minRadius = 0, maxRadius = 0)
circles = np.uint16(np.around(circles))

for c in circles[0,:]:

    center = (c[0],c[1])
    radius = c[2]

    # 바깥원
    cv2.circle(img_color,center,radius,(0,255,0),3)

    # 중심원
    cv2.circle(img_color,center,2,(0,0,255),3)



gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV, 11, 1)

kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=4)

cont_img = closing.copy()
contours, hierarchy = cv2.findContours(cont_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    area = cv2.contourArea(cnt)
    if area < 200 or area > 6500:
        continue

    if len(cnt) < 5:
        continue

    ellipse = cv2.fitEllipse(cnt)
    cv2.ellipse(img, ellipse, (0, 255, 0), 2)

cv2.imshow('detected circles',img_color)
cv2.imshow("Morphological Closing", closing)
cv2.imshow("Adaptive Threshold", thresh)
# cv2.imshow("contours", img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e354e008e341> in <module>
#       1 img = cv2.imread('sIMG_8256.jpg',1)
#       2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 3 img_gray = cv2.medianBlur(img_gray,5)
#       4 img_color = cv2.cvtColor(img_gray,cv2.COLOR_GRAY2BGR)
#       5
#
# NameError: name 'img_gray' is not defined
